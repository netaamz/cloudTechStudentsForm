# %% [markdown]
# <a href="https://colab.research.google.com/github/netaamz/cloudTechStudentsForm/blob/main/cloudProjectPart1_q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
from google.colab import drive
drive.mount('/content/drive')
x = {
    "Students":[{
"First name": "Maxim",
"Last name": "Lebedinsky",
"Email":"Maxim.Lebedinsky@e.braude.ac.il",
"Courses":("Web, ML, AI, Cloud, Physics, Differ. Equ"),
"Link":"https://github.com/MaximL98"
    }]
}
with open('/content/drive/MyDrive/Cloud/students.json', "w") as fid:
  json.dump(x, fid)

with open('/content/drive/MyDrive/Cloud/students.json', "r") as fid:
  z = json.load(fid)
print(z)
for key in z:
  print(key+":\t", z[key])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'Students': [{'First name': 'Maxim', 'Last name': 'Lebedinsky', 'Email': 'Maxim.Lebedinsky@e.braude.ac.il', 'Courses': 'Web, ML, AI, Cloud, Physics, Differ. Equ', 'Link': 'https://github.com/MaximL98'}]}
# Students:	 [{'First name': 'Maxim', 'Last name': 'Lebedinsky', 'Email': 'Maxim.Lebedinsky@e.braude.ac.il', 'Courses': 'Web, ML, AI, Cloud, Physics, Differ. Equ', 'Link': 'https://github.com/MaximL98'}]

# %%
import json
#@title Student Selection
student = "Maxim" #@param ["Maxim", "Rotem"] {allow-input: true}
favoriteTvShow = "The Boys" #@param {type:"string"}


with open('/content/drive/My Drive/Cloud/students.json', 'r') as file:
  studentsInfo = json.load(file)
  found = False
  for info in studentsInfo['Students']:    
    if info.get('First name') == student:
      info['Favorite Tv Show'] = favoriteTvShow
      with open('/content/drive/My Drive/Cloud/students.json', 'w') as json_file:
          json.dump(studentsInfo, json_file)
      found = True
      print(info)
  if(not found):
    print("Student named {} have not been found...".format(student))

    

file.close()
# Out:
# {'First name': 'Maxim', 'Last name': 'Lebedinsky', 'Email': 'Maxim.Lebedinsky@e.braude.ac.il', 'Courses': 'Web, ML, AI, Cloud, Physics, Differ. Equ', 'Link': 'https://github.com/MaximL98', 'Favorite Tv Show': 'The Boys'}

# %%
import json 
from google.colab import drive
drive.mount('/content/drive')
import IPython
from typing import Text
from ipywidgets import widgets

with open("/content/drive/My Drive/students.json", "r") as fid:
  data=json.load(fid)

#get students names
studentsNames=[]
courses=[]
studentsNames.append(' ')
for name in data['Students']:
  studentsNames.append(name['First name']+' '+name['Last name'])
# create dropdown list widget
dropdown_list = widgets.Dropdown(
    value=' ',
    options=studentsNames,
    description='Student :',
    disabled=False
)
# create text box widget for displayin email
email_text = widgets.HTML(
    placeholder='aaa@aaa.com',
    description='Email:',
    disabled=True
)

courses_widget = widgets.HTML('<ul><li>' + '</li><li>'.join(courses) + '</li></ul>')
accordion = widgets.Accordion(children=[courses_widget], titles=('HTML'))
accordion.set_title(0,'Courses')

# create text box widget for updating TV Show field
tv_show_text = widgets.Text(
    value='',
    placeholder='Enter TV Show',
    description='TV Show:',
    disabled=True
)

# create button widget for updating button
update_button = widgets.Button(
    description='Update TV Show',
     disabled=True,
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)
# create button widget for link
link_button = widgets.Button(
    description='Open Link',
    disabled=True,
    button_style='info', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='intresting link to click on',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)

link_widg= widgets.Label(
    value ='',
    placeholder='http',
    description='Link:',
    disabled=True
    )

output = widgets.Output()

# define function to update output when dropdown list value changes
def update_output(change):
    selected_student = change['new']
    link_button.disabled=False
    update_button.disabled=False
    for student in data['Students']:
        if selected_student == student['First name'] + ' ' + student['Last name']:
            with output:
                output.clear_output()
                courses=[]
                #shows email, and allowes to send one
                email_text.value='<a href="mailto:{address}">{address}</a>'.format(address=student['Email'])
                for c in student['Courses']:
                  courses.append(c)
                courses_widget = widgets.HTML('<ul><li>' + '</li><li>'.join(courses) + '</li></ul>')
                accordion.children = [courses_widget]
                link_widg.value= student['Link']
                if 'TV Show' in student:
                    tv_show_text.value= student['TV Show']

# define function to update TV Show field for selected student
def update_tv_show(b):
    selected_student = dropdown_list.value
    for student in data['Students']:
        if selected_student == student['First name'] + ' ' + student['Last name']:
            student['TV Show'] = tv_show_text.value
            with open("/content/drive/My Drive/students.json", "w") as fid:
              json.dump(data,fid)
            tv_show_text.value = ''
            with output:
                output.clear_output()
                print('TV Show updated successfully for', selected_student)
            break

def open_url_in_new_tab(url):
    html = '<script>window.open("{url}", "_blank");</script>'.format(url=url)
    display(widgets.HTML(html))

link_button = widgets.Button(description='Open Link')
link_widg = widgets.Text(description='Link:')

def on_button_click(link_button):
    open_url_in_new_tab(link_widg.value)

link_button.on_click(on_button_click)
dropdown_list.observe(update_output, names='value')
update_button.on_click(update_tv_show)
display(dropdown_list,email_text,accordion,link_widg,link_button, tv_show_text, update_button, output)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dropdown(description='Student :', options=(' ', 'Maxim Lebedinsky', 'Neta Amzalag', 'Peleg Oanuno', 'Vital Mar…
# HTML(value='', description='Email:', placeholder='aaa@aaa.com')
# Accordion(children=(HTML(value='<ul><li></li></ul>'),), _titles={'0': 'Courses'})
# Text(value='', description='Link:')
# Button(description='Open Link', style=ButtonStyle())
# Text(value='', description='TV Show:', disabled=True, placeholder='Enter TV Show')
# Button(button_style='success', description='Update TV Show', disabled=True, icon='check', style=ButtonStyle(),…
# Output()
